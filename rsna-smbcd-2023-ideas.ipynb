# %% [markdown]
# # Create a new classification head
# * https://forums.fast.ai/t/how-to-add-additional-layers-in-any-pretrained-model-like-resnet34/72371
# * https://towardsdatascience.com/getting-started-with-pytorch-image-models-timm-a-practitioners-guide-4e77b4bf9055
#
# ![image.png](attachment:df28e427-9953-4c5a-af2b-07395a67b79e.png)

# %% [markdown]
# # Deal with Class Imbalance
# * http://ethen8181.github.io/machine-learning/model_selection/imbalanced/imbalanced_metrics.html
#  * Oversampling example: https://www.kaggle.com/code/tanlikesmath/oversampling-mnist-with-fastai/notebook

# %% [markdown]
# # Multi-Modal Classification
#
#  * https://forums.fast.ai/t/combining-tabular-images-in-fastai2-and-should-work-with-almost-any-other-type/73197
#  * https://ai.facebook.com/research/publications/what-makes-training-multi-modal-classification-networks-hard/

# %% [markdown]
# # Add More Positive Training Images
#
# Some were shared in the Kaggle discussions

# %% [markdown]
# # Various Links
# * https://www.kaggle.com/code/qitvision/a-complete-ml-pipeline-fast-ai
# * https://gist.github.com/alalbiol/da9415a53d359b19fc1d214950e2beb8 -- custom metrics in FastAI
# * https://ar5iv.labs.arxiv.org/html/1812.01187

# %% [markdown]
# # Multiple Instance Learning (MIL)
# * https://forums.fast.ai/t/mil-question-variable-length-bags-of-images/97413
# * https://ar5iv.labs.arxiv.org/html/2108.10612
#    - https://github.com/apardyl/ProtoMIL
# * https://medium.com/swlh/multiple-instance-learning-c49bd21f5620
# ![image.png](attachment:535c527a-78b3-4df1-a48f-911e8d50d1f2.png)

# %% [markdown]
# # Optimize Data Loader
#  * https://github.com/NVIDIA/DALI
#  * https://towardsdatascience.com/hdf5-datasets-for-pytorch-631ff1d750f5
#  * https://towardsdatascience.com/reading-h5-files-faster-with-pytorch-datasets-3ff86938cc
#  * https://discuss.pytorch.org/t/how-to-speed-up-the-data-loader/13740
#  * https://zarr.readthedocs.io/en/stable/

# %% [markdown]
# # Try Different Loss Functions
#  * https://www.kaggle.com/competitions/rsna-breast-cancer-detection/discussion/369704
